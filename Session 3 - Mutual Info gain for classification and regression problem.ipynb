# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.datasets import load_boston
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_wine

# %%
data=load_wine()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['Target']=data.target
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df['Target'].value_counts()
# Out:
# 1    71
# 0    59
# 2    48
# Name: Target, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
X=df.drop(columns=['Target'],axis=1)
y=df[['Target']]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=1)

# %% [markdown]
# ### Mutual Info Gain for Classification Problem

# %%
from sklearn.feature_selection import mutual_info_classif
# Determine the mutual information 
mutual_info=mutual_info_classif(X_train,y_train)
mutual_info
# Out:
# array([0.40973212, 0.30329003, 0.08648625, 0.23979627, 0.17334185,
#        0.47348591, 0.6597241 , 0.09608948, 0.21918403, 0.54092784,
#        0.46278457, 0.49478864, 0.59719855])

# %%
mutual_info=pd.Series(mutual_info)
mutual_info.index=X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# flavanoids                      0.659724
# proline                         0.597199
# color_intensity                 0.540928
# od280/od315_of_diluted_wines    0.494789
# total_phenols                   0.473486
# hue                             0.462785
# alcohol                         0.409732
# malic_acid                      0.303290
# alcalinity_of_ash               0.239796
# proanthocyanins                 0.219184
# magnesium                       0.173342
# nonflavanoid_phenols            0.096089
# ash                             0.086486
# dtype: float64

# %%
from sklearn.feature_selection import SelectKBest

sel_five_cols=SelectKBest(mutual_info_classif,k=5)
sel_five_cols.fit(X_train,y_train)
X_train.columns[sel_five_cols.get_support()]
# Out:
# Index(['flavanoids', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines',
#        'proline'],
#       dtype='object')

# %% [markdown]
# ### Mutual Info Gain for Regression Problem

# %%
house_df=pd.read_csv('C:\\Users\\Dell\\Data Science\\CampusX Tutorial\\Feature Selection\\test.csv')
house_df_feature=pd.read_csv('C:\\Users\\Dell\\Data Science\\CampusX Tutorial\\Feature Selection\\sample_submission.csv')

house_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
(house_df.columns[house_df.dtypes=='object'])
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
house_df_int= [columns for columns in house_df 
               if columns not in house_df.columns[house_df.dtypes=='object']]
len(house_df_int)
# Out:
# 37

# %%
house_df=house_df[house_df_int]
house_df.drop(columns=['Id'],inplace=True)
house_df
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             20         80.0    11622            5            6       1961
# 1             20         81.0    14267            6            6       1958
# 2             60         74.0    13830            5            5       1997
# 3             60         78.0     9978            6            6       1998
# 4            120         43.0     5005            8            5       1992
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %%
house_df['SalesPrice']=house_df_feature['SalePrice']

# %%
X=house_df.drop(columns=['SalesPrice'],axis=1)
y=house_df[['SalesPrice']]

# %%
X.fillna(0,inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=1)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((1167, 36), (292, 36), (1167, 1), (292, 1))

# %%
from sklearn.feature_selection import mutual_info_regression

mutual_info= mutual_info_regression(X_train.fillna(0),y_train)

# %%
mutual_info=pd.Series(mutual_info)
mutual_info.index=X_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# BedroomAbvGr     0.644442
# LotArea          0.444399
# TotRmsAbvGrd     0.320212
# MSSubClass       0.294108
# GrLivArea        0.240846
# LotFrontage      0.146097
# 2ndFlrSF         0.126385
# TotalBsmtSF      0.088681
# 1stFlrSF         0.087134
# FullBath         0.086110
# GarageArea       0.072649
# OverallQual      0.066820
# WoodDeckSF       0.058183
# MoSold           0.057945
# GarageCars       0.051073
# YearBuilt        0.046421
# MasVnrArea       0.044706
# HalfBath         0.035440
# BsmtFinSF1       0.032641
# BsmtUnfSF        0.029518
# KitchenAbvGr     0.027841
# OpenPorchSF      0.026463
# GarageYrBlt      0.025063
# BsmtFullBath     0.022793
# YearRemodAdd     0.022341
# OverallCond      0.016299
# Fireplaces       0.015708
# YrSold           0.015461
# EnclosedPorch    0.009318
# BsmtFinSF2       0.003984
# ScreenPorch      0.003719
# MiscVal          0.001437
# BsmtHalfBath     0.000000
# 3SsnPorch        0.000000
# PoolArea         0.000000
# ...

# %%
from sklearn.feature_selection import SelectPercentile
select_top_col = SelectPercentile(mutual_info_regression,percentile=20)
select_top_col.fit(X_train,y_train)
X_train.columns[select_top_col.get_support()]
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', '2ndFlrSF', 'GrLivArea',
#        'BedroomAbvGr', 'TotRmsAbvGrd'],
#       dtype='object')

# %% [markdown]
# ### THE END
